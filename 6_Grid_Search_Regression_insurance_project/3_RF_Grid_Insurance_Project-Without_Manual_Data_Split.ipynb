# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[50,100]} 



grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
#grid.fit(X_train, y_train)
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
#grid_predictions = grid.predict(X_test) 
   
# print classification report 
#from sklearn.metrics import r2_score
#r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.196601      0.007089         0.014199        0.001721
# 1        0.387306      0.016663         0.023800        0.001600
# 2        0.142600      0.007526         0.015599        0.002417
# 3        0.295932      0.015781         0.023399        0.001020
# 4        0.158411      0.009458         0.016402        0.002871
# 5        0.291597      0.012564         0.027402        0.004224
# 6        0.209398      0.008014         0.016601        0.003199
# 7        0.408998      0.024915         0.023800        0.003310
# 8        0.153599      0.014066         0.018801        0.004957
# 9        0.310800      0.020528         0.028800        0.005776
# 10       0.166001      0.016888         0.015201        0.001469
# 11       0.289596      0.006975         0.023401        0.003930
# 12       1.469798      0.051914         0.012199        0.001168
# 13       2.793398      0.039682         0.020400        0.001202
# 14       0.828197      0.028525         0.011802        0.000399
# 15       1.615791      0.021921         0.022999        0.002282
# 16       0.799999      0.020513         0.013400        0.001962
# 17       1.695531      0.060660         0.021798        0.002041
# 18       0.360398      0.012563         0.014402        0.001021
# 19       0.760518      0.046729         0.027600        0.010837
# 20       0.214305      0.011661         0.013001        0.000002
# 21       0.454702      0.013897         0.023602        0.002058
# 22       0.220801      0.006243         0.013800        0.003251
# 23       0.306998      0.013711         0.013200        0.000400
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 50
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 50
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 50
# 5    squared_error               log2                100
# 6     friedman_mse               auto                 50
# 7     friedman_mse               auto                100
# 8     friedman_mse               sqrt                 50
# 9     friedman_mse               sqrt                100
# 10    friedman_mse               log2                 50
# 11    friedman_mse               log2                100
# 12  absolute_error               auto                 50
# 13  absolute_error               auto                100
# 14  absolute_error               sqrt                 50
# 15  absolute_error               sqrt                100
# 16  absolute_error               log2                 50
# 17  absolute_error               log2                100
# 18         poisson               auto                 50
# 19         poisson               auto                100
# 20         poisson               sqrt                 50
# 21         poisson               sqrt                100
# 22         poisson               log2                 50
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.842235
# 1   {'criterion': 'squared_error', 'max_features':...           0.843123
# 2   {'criterion': 'squared_error', 'max_features':...           0.862165
# 3   {'criterion': 'squared_error', 'max_features':...           0.858547
# 4   {'criterion': 'squared_error', 'max_features':...           0.857840
# 5   {'criterion': 'squared_error', 'max_features':...           0.857435
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.842896
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.847452
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.857234
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.862382
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.858249
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.861404
# 12  {'criterion': 'absolute_error', 'max_features'...           0.843407
# 13  {'criterion': 'absolute_error', 'max_features'...           0.837959
# 14  {'criterion': 'absolute_error', 'max_features'...           0.860015
# 15  {'criterion': 'absolute_error', 'max_features'...           0.857229
# 16  {'criterion': 'absolute_error', 'max_features'...           0.851717
# 17  {'criterion': 'absolute_error', 'max_features'...           0.854677
# 18  {'criterion': 'poisson', 'max_features': 'auto...           0.817755
# 19  {'criterion': 'poisson', 'max_features': 'auto...           0.820104
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.802302
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.809202
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.799580
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.807040
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.768387           0.861443           0.820249
# 1            0.773094           0.859667           0.818655
# 2            0.775778           0.859691           0.830172
# 3            0.778442           0.859163           0.827567
# 4            0.777406           0.858750           0.830856
# 5            0.782054           0.862243           0.827915
# 6            0.773936           0.856908           0.823988
# 7            0.775145           0.852770           0.817019
# 8            0.768041           0.860710           0.823805
# 9            0.784767           0.866162           0.830591
# 10           0.772689           0.862552           0.829673
# 11           0.782767           0.859263           0.828955
# 12           0.769975           0.847851           0.825426
# 13           0.769705           0.848212           0.818557
# 14           0.779829           0.847570           0.829249
# 15           0.785584           0.856585           0.830510
# 16           0.781088           0.854810           0.833725
# 17           0.775773           0.858968           0.829154
# 18           0.752706           0.826980           0.821300
# 19           0.752103           0.823237           0.828272
# 20           0.724251           0.829346           0.787341
# 21           0.729333           0.820767           0.789809
# 22           0.719691           0.821076           0.789380
# 23           0.721030           0.827235           0.794095
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.831447         0.824752        0.031286               17
# 1            0.834964         0.825901        0.029530               14
# 2            0.836447         0.832851        0.031168                8
# 3            0.842031         0.833150        0.029748                5
# 4            0.839981         0.832967        0.029746                6
# 5            0.839605         0.833850        0.028683                4
# 6            0.832690         0.826084        0.028285               13
# 7            0.835924         0.825662        0.028077               15
# 8            0.833785         0.828715        0.033371               12
# 9            0.843423         0.837465        0.029340                1
# 10           0.835179         0.831669        0.032110               11
# 11           0.838230         0.834124        0.028486                3
# 12           0.838393         0.825010        0.028525               16
# 13           0.836600         0.822206        0.027933               18
# 14           0.847877         0.832908        0.028301                7
# 15           0.841492         0.834280        0.026312                2
# 16           0.838637         0.831995        0.026639               10
# 17           0.845610         0.832836        0.030308                9
# 18           0.810048         0.805758        0.027088               19
# 19           0.801151         0.804974        0.027983               20
# 20           0.771749         0.782998        0.034978               23
# 21           0.779146         0.785652        0.031683               22
# 22           0.774962         0.780938        0.034108               24
# 23           0.785949         0.787070        0.035844               21

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:26
# BMI:26
# Children:3
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[18691.2457119]
# C:\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   "X does not have valid feature names, but"
