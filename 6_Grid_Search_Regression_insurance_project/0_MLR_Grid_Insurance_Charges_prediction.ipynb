# %%
#1_MLR_Evaluation_Metrics_Analysis_Insurance_Charges
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')
dataset = pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#identifying inputs
input_var=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
#identifying output
output_var=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(input_var,output_var,test_size=1/3, random_state=0)

# %%
#1# MLR_Model_Creation
#from sklearn.linear_model import LinearRegression
#MLR_regressor_variable=LinearRegression()
#MLR_regressor_variable.fit(x_train,y_train)

# %%
#we got weight and bias
#weight=MLR_regressor_variable.coef_
#bais=MLR_regressor_variable.intercept_
#weight = array([  260.1423112 ,   315.22441969,   545.72248029,   -71.76915955,       23252.13608407])
#bais = -12013.76012735222

# %%
#Predition test
#y_predict=MLR_regressor_variable.predict(x_test)
#y_predict

# %%
#Evaluate Predition metrics
#from sklearn.metrics import r2_score
#r_score= r2_score(y_test,y_predict)   
#r_score
#MLR_r^2_Score=0.7865108093853883

# %%
#we are going to standardization as the model got bad r2_value (0.78651)
#so after standardization we shall check whether r2_value improved
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
#fit_transform will train model with standardization
#x_test=sc.transform(x_test)

# %%
#2# Again MLR_Model_Creation after Standarization
#from sklearn.linear_model import LinearRegression
#MLR_STD_regressor_variable=LinearRegression()
#MLR_STD_regressor_variable.fit(x_train,y_train)

# %%
#Predition test after standardization
#y_predict_std=MLR_STD_regressor_variable.predict(x_test)
#y_predict_std

# %%
#Evaluate Predition metrics
#from sklearn.metrics import r2_score
#r_score_std= r2_score(y_test,y_predict_std)   
#r_score_std
#After_Standarization_MLR_r^2_Score=0.7865108093853883 remains same

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
reg = Ridge()
parameters = {
    "alpha": [1, 10, 100, 290, 500],
    "fit_intercept": [True, False],
    "solver": ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']
}
grid = GridSearchCV(estimator=reg, param_grid=parameters, cv=2, n_jobs=-1)
grid.fit(x_train, y_train)
best_model = grid.best_estimator_
print("Best model parameters:", grid.best_params_)
print("Test score:", best_model.score(x_train, y_train))
# Out:
# Best model parameters: {'alpha': 1, 'fit_intercept': True, 'solver': 'sag'}
# Test score: 0.7277167923428421

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.016001  9.994507e-04         0.001499    4.981756e-04           1
# 1        0.023000  4.001975e-03         0.001502    5.013943e-04           1
# 2        0.015499  4.980564e-04         0.001001    4.768372e-07           1
# 3        0.004001  9.996891e-04         0.000997    1.192093e-07           1
# 4        0.005000  9.992123e-04         0.001499    5.004406e-04           1
# ..            ...           ...              ...             ...         ...
# 65       0.003002  9.536743e-07         0.000998    1.668930e-06         500
# 66       0.002000  9.536743e-07         0.001000    2.384186e-07         500
# 67       0.002502  5.002022e-04         0.000999    9.989738e-04         500
# 68       0.003000  9.536743e-07         0.001001    4.768372e-07         500
# 69       0.003500  5.018711e-04         0.001000    1.192093e-06         500
#
#    param_fit_intercept param_solver  \
# 0                 True         auto
# 1                 True          svd
# 2                 True     cholesky
# 3                 True         lsqr
# 4                 True    sparse_cg
# ..                 ...          ...
# 65               False     cholesky
# 66               False         lsqr
# 67               False    sparse_cg
# 68               False          sag
# 69               False         saga
#
#                                                params  split0_test_score  \
# 0   {'alpha': 1, 'fit_intercept': True, 'solver': ...           0.710349
# 1   {'alpha': 1, 'fit_intercept': True, 'solver': ...           0.710349
# 2   {'alpha': 1, 'fit_intercept': True, 'solver': ...           0.710349
# 3   {'alpha': 1, 'fit_intercept': True, 'solver': ...           0.710332
# 4   {'alpha': 1, 'fit_intercept': True, 'solver': ...           0.710138
# ..                                                ...                ...
# 65  {'alpha': 500, 'fit_intercept': False, 'solver...          -0.731418
# 66  {'alpha': 500, 'fit_intercept': False, 'solver...          -0.731414
# 67  {'alpha': 500, 'fit_intercept': False, 'solver...          -0.731414
# 68  {'alpha': 500, 'fit_intercept': False, 'solver...          -0.731440
# 69  {'alpha': 500, 'fit_intercept': False, 'solver...          -0.731522
#
#     split1_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.713708         0.712029        0.001680                5
# 1            0.713708         0.712029        0.001680                4
# 2            0.713708         0.712029        0.001680                5
# 3            0.713729         0.712031        0.001698                3
# 4            0.713729         0.711933        0.001796                7
# ..                ...              ...             ...              ...
# 65          -0.795586        -0.763502        0.032084               68
# 66          -0.795564        -0.763489        0.032075               65
# 67          -0.795586        -0.763500        0.032086               66
# 68          -0.795431        -0.763435        0.031995               64
# 69          -0.795525        -0.763523        0.032002               70
#
# [70 rows x 13 columns]

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:26
# BMI:26
# Children:3
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[168688.05672472]
