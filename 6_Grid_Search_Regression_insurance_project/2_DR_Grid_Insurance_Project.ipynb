# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
              'max_features': ['auto','sqrt','log2'],
              'splitter':['best','random']} 



grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   
# print classification report 
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)

#print(re)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'auto', 'splitter': 'best'}: 0.6946984788856039

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006798      0.000747         0.001400        0.000488
# 1        0.004800      0.001469         0.001601        0.000489
# 2        0.004000      0.000631         0.002399        0.001855
# 3        0.003601      0.000491         0.001600        0.000490
# 4        0.004998      0.001263         0.001401        0.000491
# 5        0.003600      0.000799         0.001801        0.000748
# 6        0.005399      0.000489         0.001400        0.000489
# 7        0.004200      0.000400         0.001400        0.000490
# 8        0.004600      0.000491         0.002001        0.000632
# 9        0.003799      0.000402         0.001400        0.000488
# 10       0.005003      0.000628         0.001397        0.000487
# 11       0.004399      0.000490         0.001601        0.000490
# 12       0.036401      0.001360         0.001202        0.000401
# 13       0.026599      0.001354         0.001202        0.000398
# 14       0.020999      0.001414         0.001400        0.000490
# 15       0.017598      0.001498         0.001203        0.000402
# 16       0.022000      0.002529         0.001399        0.000489
# 17       0.019398      0.002245         0.001003        0.000002
# 18       0.009801      0.000750         0.001600        0.000489
# 19       0.004601      0.000493         0.001200        0.000399
# 20       0.006601      0.000488         0.001601        0.000490
# 21       0.004999      0.000894         0.001201        0.000399
# 22       0.009800      0.005419         0.002200        0.001471
# 23       0.004800      0.001327         0.001399        0.000489
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               auto           best
# 7     friedman_mse               auto         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               auto           best
# 13  absolute_error               auto         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               auto           best
# 19         poisson               auto         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.683481
# 1   {'criterion': 'squared_error', 'max_features':...           0.626262
# 2   {'criterion': 'squared_error', 'max_features':...           0.612465
# 3   {'criterion': 'squared_error', 'max_features':...           0.722974
# 4   {'criterion': 'squared_error', 'max_features':...           0.597222
# 5   {'criterion': 'squared_error', 'max_features':...           0.545660
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.717118
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.739447
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.616796
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.619978
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.605415
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.533981
# 12  {'criterion': 'absolute_error', 'max_features'...           0.626556
# 13  {'criterion': 'absolute_error', 'max_features'...           0.634789
# 14  {'criterion': 'absolute_error', 'max_features'...           0.539670
# 15  {'criterion': 'absolute_error', 'max_features'...           0.644409
# 16  {'criterion': 'absolute_error', 'max_features'...           0.709562
# 17  {'criterion': 'absolute_error', 'max_features'...           0.634210
# 18  {'criterion': 'poisson', 'max_features': 'auto...           0.528140
# 19  {'criterion': 'poisson', 'max_features': 'auto...           0.645735
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.500623
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.421163
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.555155
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.494742
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.502505           0.776848           0.592397
# 1            0.550063           0.740077           0.494600
# 2            0.540821           0.638948           0.723882
# 3            0.568351           0.702866           0.511350
# 4            0.574751           0.694999           0.626011
# 5            0.604217           0.653480           0.548068
# 6            0.498793           0.758163           0.644080
# 7            0.587263           0.644180           0.402929
# 8            0.666159           0.588489           0.559476
# 9            0.399774           0.576226           0.409958
# 10           0.393424           0.750924           0.599713
# 11           0.590710           0.601870           0.558523
# 12           0.526132           0.686067           0.595094
# 13           0.658690           0.710340           0.627295
# 14           0.387357           0.669650           0.662851
# 15           0.547912           0.734591           0.674277
# 16           0.663123           0.710867           0.434623
# 17           0.675207           0.485472           0.601692
# 18           0.513792           0.664102           0.625293
# 19           0.416515           0.587413           0.475472
# 20           0.459405           0.483500           0.433576
# 21           0.597364           0.661181           0.564766
# 22           0.601454           0.574988           0.513121
# 23           0.584846           0.582565           0.462524
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.663177         0.643681        0.091933                3
# 1            0.626438         0.607488        0.082865                8
# 2            0.558365         0.614896        0.065031                6
# 3            0.516077         0.604324        0.091120                9
# 4            0.507906         0.600178        0.061364               12
# 5            0.505834         0.571452        0.051614               18
# 6            0.669871         0.657605        0.088553                1
# 7            0.610647         0.596893        0.109965               14
# 8            0.586154         0.603415        0.036242               10
# 9            0.649032         0.530994        0.105608               21
# 10           0.646955         0.599286        0.116347               13
# 11           0.605108         0.578038        0.027507               16
# 12           0.639431         0.614656        0.053055                7
# 13           0.615453         0.649313        0.033629                2
# 14           0.493725         0.550651        0.106560               19
# 15           0.610783         0.642394        0.062365                4
# 16           0.671187         0.637872        0.103465                5
# 17           0.620397         0.603396        0.063725               11
# 18           0.633636         0.592992        0.060383               15
# 19           0.491398         0.523307        0.082230               22
# 20           0.531846         0.481790        0.033731               24
# 21           0.619298         0.572754        0.082018               17
# 22           0.454565         0.539857        0.051482               20
# 23           0.453958         0.515727        0.057151               23

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:26
# BMI:26
# Children:3
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[63770.42801]
