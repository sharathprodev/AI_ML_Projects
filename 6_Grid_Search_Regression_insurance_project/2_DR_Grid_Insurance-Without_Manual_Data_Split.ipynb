# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
indep2 = sc.fit_transform(indep)
#X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
              'max_features': ['auto','sqrt','log2'],
              'splitter':['best','random']} 



grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
#grid.fit(X_train, y_train) 
grid.fit(indep2, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
#grid_predictions = grid.predict(X_test) 
   
# print classification report 
#from sklearn.metrics import r2_score
#r_score=r2_score(y_test,grid_predictions)

#print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
print("The R_score value for best parameter {}:".format(grid.best_params_))
#print(re)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006800      0.002136         0.001200    4.025701e-04
# 1        0.005001      0.000895         0.000999    8.996946e-07
# 2        0.004000      0.000633         0.001201    3.992590e-04
# 3        0.003199      0.000401         0.000801    4.004251e-04
# 4        0.003001      0.000002         0.001399    4.902915e-04
# 5        0.003401      0.000489         0.000799    3.995188e-04
# 6        0.006801      0.002400         0.001000    6.324868e-04
# 7        0.003601      0.000490         0.000799    3.994953e-04
# 8        0.004200      0.000980         0.001001    1.435272e-06
# 9        0.003200      0.000399         0.000200    4.003525e-04
# 10       0.004201      0.000400         0.000799    3.995445e-04
# 11       0.003201      0.000400         0.000801    7.492205e-04
# 12       0.040399      0.001021         0.001201    4.000918e-04
# 13       0.039402      0.010306         0.001599    8.004249e-04
# 14       0.022800      0.002399         0.000999    7.168434e-07
# 15       0.028198      0.008447         0.002401    2.333962e-03
# 16       0.024201      0.002481         0.001199    4.004719e-04
# 17       0.018200      0.002039         0.001600    4.909946e-04
# 18       0.010799      0.001937         0.001200    4.002821e-04
# 19       0.004400      0.000799         0.000999    1.564142e-06
# 20       0.005600      0.000799         0.001000    2.020800e-06
# 21       0.003600      0.000491         0.000799    7.475261e-04
# 22       0.003005      0.000008         0.000395    4.838768e-04
# 23       0.002600      0.001020         0.000400    4.899215e-04
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               auto           best
# 7     friedman_mse               auto         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               auto           best
# 13  absolute_error               auto         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               auto           best
# 19         poisson               auto         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.727600
# 1   {'criterion': 'squared_error', 'max_features':...           0.716731
# 2   {'criterion': 'squared_error', 'max_features':...           0.597194
# 3   {'criterion': 'squared_error', 'max_features':...           0.715862
# 4   {'criterion': 'squared_error', 'max_features':...           0.726138
# 5   {'criterion': 'squared_error', 'max_features':...           0.654763
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.725234
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.673691
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.634522
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.651293
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.736982
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.741874
# 12  {'criterion': 'absolute_error', 'max_features'...           0.734276
# 13  {'criterion': 'absolute_error', 'max_features'...           0.640096
# 14  {'criterion': 'absolute_error', 'max_features'...           0.653976
# 15  {'criterion': 'absolute_error', 'max_features'...           0.689065
# 16  {'criterion': 'absolute_error', 'max_features'...           0.705222
# 17  {'criterion': 'absolute_error', 'max_features'...           0.692458
# 18  {'criterion': 'poisson', 'max_features': 'auto...           0.717527
# 19  {'criterion': 'poisson', 'max_features': 'auto...           0.623712
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.678276
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.659298
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.707625
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.680309
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.653516           0.735132           0.732513
# 1            0.598700           0.713512           0.671060
# 2            0.615076           0.732266           0.674849
# 3            0.595641           0.676984           0.572060
# 4            0.563109           0.722491           0.703483
# 5            0.484923           0.661236           0.706036
# 6            0.648860           0.740491           0.714161
# 7            0.603368           0.723940           0.703082
# 8            0.614771           0.584673           0.610576
# 9            0.572659           0.655563           0.670797
# 10           0.623671           0.744221           0.736814
# 11           0.596176           0.775892           0.629587
# 12           0.587258           0.742637           0.715506
# 13           0.568901           0.736953           0.745172
# 14           0.404382           0.655433           0.676375
# 15           0.391005           0.574547           0.662109
# 16           0.586248           0.685393           0.646002
# 17           0.541973           0.725973           0.742719
# 18           0.654753           0.723388           0.731459
# 19           0.544079           0.647609           0.677402
# 20           0.470235           0.664127           0.651093
# 21           0.494876           0.644040           0.679348
# 22           0.393256           0.612828           0.701807
# 23           0.496202           0.704470           0.686871
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.676908         0.705134        0.033512                3
# 1            0.691314         0.678264        0.043069               11
# 2            0.686996         0.661276        0.049247               12
# 3            0.680966         0.648303        0.054845               15
# 4            0.723555         0.687755        0.062842                6
# 5            0.675137         0.636419        0.077781               17
# 6            0.696052         0.704959        0.031574                4
# 7            0.725456         0.685908        0.045316                7
# 8            0.751873         0.639283        0.058492               16
# 9            0.589295         0.627921        0.039229               19
# 10           0.689512         0.706240        0.045650                1
# 11           0.683235         0.685353        0.067021                8
# 12           0.747443         0.705424        0.060079                2
# 13           0.722096         0.682644        0.068064                9
# 14           0.701369         0.618307        0.108338               21
# 15           0.561212         0.575588        0.104539               24
# 16           0.671516         0.658876        0.041113               13
# 17           0.703935         0.681411        0.071857               10
# 18           0.679292         0.701284        0.029366                5
# 19           0.629382         0.624436        0.044328               20
# 20           0.510852         0.594916        0.086611               23
# 21           0.698423         0.635197        0.072520               18
# 22           0.619247         0.606953        0.114004               22
# 23           0.689526         0.651476        0.078039               14

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:26
# BMI:26
# Children:3
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19023.26]
