# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.0.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')
dataset = pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
input_var=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
output_var=dataset['charges']

# %%
input_var
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
output_var
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(input_var,output_var,test_size=1/3, random_state=0)

# %%
x_train
# Out:
#       age    bmi  children  sex_male  smoker_yes
# 482    18  31.35         0         0           0
# 338    50  32.30         1         1           1
# 356    46  43.89         3         1           0
# 869    25  24.30         3         0           0
# 182    22  19.95         3         1           0
# ...   ...    ...       ...       ...         ...
# 763    27  26.03         0         1           0
# 835    42  35.97         2         1           0
# 1216   40  25.08         0         1           0
# 559    19  35.53         0         1           0
# 684    33  18.50         1         0           0
#
# [892 rows x 5 columns]

# %%
x_test
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 578    52  30.200         1         1           0
# 610    47  29.370         1         0           0
# 569    48  40.565         2         1           1
# 1034   61  38.380         0         1           0
# 198    51  18.050         0         0           0
# ...   ...     ...       ...       ...         ...
# 261    20  26.840         1         0           1
# 1271   25  34.485         0         0           0
# 1313   19  34.700         2         0           1
# 2      28  33.000         3         1           0
# 405    52  38.380         2         0           0
#
# [446 rows x 5 columns]

# %%
y_train
# Out:
# 482      1622.1885
# 338     41919.0970
# 356      8944.1151
# 869      4391.6520
# 182      4005.4225
#            ...
# 763      3070.8087
# 835      7160.3303
# 1216     5415.6612
# 559      1646.4297
# 684      4766.0220
# Name: charges, Length: 892, dtype: float64

# %%
y_test
# Out:
# 578      9724.53000
# 610      8547.69130
# 569     45702.02235
# 1034    12950.07120
# 198      9644.25250
#            ...
# 261     17085.26760
# 1271     3021.80915
# 1313    36397.57600
# 2        4449.46200
# 405     11396.90020
# Name: charges, Length: 446, dtype: float64

# %%
#1# MLR_Model_Creation
from sklearn.linear_model import LinearRegression
MLR_regressor_variable=LinearRegression()
MLR_regressor_variable.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#we got weight and bias
weight=MLR_regressor_variable.coef_
bais=MLR_regressor_variable.intercept_
#weight = array([  260.1423112 ,   315.22441969,   545.72248029,   -71.76915955,       23252.13608407])
#bais = -12013.76012735222

# %%
weight
# Out:
# array([  260.1423112 ,   315.22441969,   545.72248029,   -71.76915955,
#        23252.13608407])

# %%
bais
# Out:
# -12013.76012735222

# %%
#Predition test
y_predict=MLR_regressor_variable.predict(x_test)
y_predict
# Out:
# array([ 1.15073709e+04,  1.00167922e+04,  3.75319613e+04,  1.58814649e+04,
#         6.94329852e+03,  3.49723126e+03,  9.63932078e+02,  1.43601057e+04,
#         9.03174486e+03,  7.40849640e+03,  4.45750987e+03,  1.03499847e+04,
#         9.14329188e+03,  4.23404178e+03,  2.71743452e+04,  1.15072425e+04,
#         1.11892673e+04,  5.46553468e+03,  8.11479002e+03,  2.60421143e+04,
#         3.33412991e+04,  1.43065441e+04,  1.12461940e+04,  3.22377602e+04,
#         4.28273021e+03,  8.55365086e+03,  7.20454803e+02,  1.04315056e+04,
#         4.16452808e+03,  1.03250884e+04,  9.07288836e+03,  4.00290583e+04,
#         1.58326873e+04,  1.39801687e+04,  2.39501965e+04,  4.59472725e+03,
#         1.30045781e+04,  3.04704829e+04,  3.30669937e+04,  3.68605927e+03,
#         3.61014393e+03,  4.26596802e+03,  2.96372339e+04,  3.89954242e+04,
#         2.75369574e+04,  4.84220740e+03,  1.14032185e+04,  7.68130087e+03,
# ...

# %%
#Evaluate Predition metrics
from sklearn.metrics import r2_score
r_score= r2_score(y_test,y_predict)   
r_score
#MLR_r^2_Score=0.7865108093853883
# Out:
# 0.7865108093853883

# %%
#we are going to standardization as the model got bad r2_value
#so after standardization we shall check whether r2_value improved
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
#fit_transform will train model with standardization
x_test=sc.transform(x_test)

# %%
#1# MLR_Model_Creation
from sklearn.linear_model import LinearRegression
MLR_regressor_variable=LinearRegression()
MLR_regressor_variable.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Predition test
y_predict=MLR_regressor_variable.predict(x_test)
y_predict
# Out:
# array([ 1.15073709e+04,  1.00167922e+04,  3.75319613e+04,  1.58814649e+04,
#         6.94329852e+03,  3.49723126e+03,  9.63932078e+02,  1.43601057e+04,
#         9.03174486e+03,  7.40849640e+03,  4.45750987e+03,  1.03499847e+04,
#         9.14329188e+03,  4.23404178e+03,  2.71743452e+04,  1.15072425e+04,
#         1.11892673e+04,  5.46553468e+03,  8.11479002e+03,  2.60421143e+04,
#         3.33412991e+04,  1.43065441e+04,  1.12461940e+04,  3.22377602e+04,
#         4.28273021e+03,  8.55365086e+03,  7.20454803e+02,  1.04315056e+04,
#         4.16452808e+03,  1.03250884e+04,  9.07288836e+03,  4.00290583e+04,
#         1.58326873e+04,  1.39801687e+04,  2.39501965e+04,  4.59472725e+03,
#         1.30045781e+04,  3.04704829e+04,  3.30669937e+04,  3.68605927e+03,
#         3.61014393e+03,  4.26596802e+03,  2.96372339e+04,  3.89954242e+04,
#         2.75369574e+04,  4.84220740e+03,  1.14032185e+04,  7.68130087e+03,
# ...

# %%
#Evaluate Predition metrics
from sklearn.metrics import r2_score
r_score= r2_score(y_test,y_predict)   
r_score
#After_Standarization_MLR_r^2_Score=0.7865108093853883 remains same
# Out:
# 0.7865108093853883

# %%
#2 using SVR kernel=rbf
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="rbf", gamma='auto', C=500)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_10=r2_score(y_test,y_pred)
r_score_10
#r_score_10=-0.0480855688697257
# Out:
# 0.6397619043375011

# %%
#2 using SVR kernel=rbf
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="rbf", gamma='auto', C=100)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_100=r2_score(y_test,y_pred)
r_score_100
#r_score_100=0.2913359565836945
# Out:
# 0.2913359565836945

# %%
#2 using SVR kernel=rbf
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="rbf", gamma='auto', C=1000)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_1000=r2_score(y_test,y_pred)
r_score_1000
#r_score_1000=0.791561827552486
# Out:
# 0.791561827552486

# %%
#2 using SVR kernel=rbf
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="rbf", gamma='auto', C=2000)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_2000=r2_score(y_test,y_pred)
r_score_2000
#r_score_2000=0.8460208706516815
# Out:
# 0.8460208706516815

# %%
#2 using SVR kernel=rbf
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="rbf", gamma='auto', C=3000)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_3000=r2_score(y_test,y_pred)
r_score_3000
#r_score_3000=0.8609984988772778
# Out:
# 0.8609984988772778

# %%
#3 using SVR kernel=poly
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="poly", gamma='auto', C=500)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_10=r2_score(y_test,y_pred)
r_score_10
#r_score_10=0.02708227122578455
# Out:
# 0.8156896311567626

# %%
#3 using SVR kernel=poly
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="poly", gamma='auto', C=100)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_100=r2_score(y_test,y_pred)
r_score_100
#r_score_100=0.6041358512938573
# Out:
# 0.604135851293857

# %%
#3 using SVR kernel=poly
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="poly", gamma='auto', C=1000)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_1000=r2_score(y_test,y_pred)
r_score_1000
#r_score_1000=0.8519826487890405
# Out:
# 0.8519826487890398

# %%
#3 using SVR kernel=poly
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="poly", gamma='auto', C=2000)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_2000=r2_score(y_test,y_pred)
r_score_2000
#r_score2000=0.8573589313885571
# Out:
# 0.8573589313885567

# %%
#3 using SVR kernel=poly
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="poly", gamma='auto', C=3000)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_2000=r2_score(y_test,y_pred)
r_score_2000
#r_score2000=0.8577898390283567
# Out:
# 0.8577898390283588

# %%
#3 using SVR kernel=sigmoid
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="sigmoid", gamma='auto', C=500)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_10=r2_score(y_test,y_pred)
r_score_10
#r_score10=0.8577898390283567
# Out:
# 0.46385498587215

# %%
#3 using SVR kernel=sigmoid
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="sigmoid", gamma='auto', C=100)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_100=r2_score(y_test,y_pred)
r_score_100
#r_score10=0.8577898390283567
# Out:
# 0.5056420492628236

# %%
#3 using SVR kernel=sigmoid
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="sigmoid", gamma='auto', C=1000)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_1000=r2_score(y_test,y_pred)
r_score_1000
#r_score10=0.8577898390283567
# Out:
# 0.18422188379861804

# %%
#3 using SVR kernel=sigmoid
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="sigmoid", gamma='auto', C=2000)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_2000=r2_score(y_test,y_pred)
r_score_2000
#r_score10=0.8577898390283567
# Out:
# -0.5786822329194656

# %%
#3 using SVR kernel=sigmoid
from sklearn.svm import SVR
SVR_regressor_variable=SVR(kernel="sigmoid", gamma='auto', C=3000)
SVR_regressor_variable.fit(x_train,y_train)
#Model is trained, lets check r2_value after prediction
y_pred=SVR_regressor_variable.predict(x_test)
from sklearn.metrics import r2_score
r_score_3000=r2_score(y_test,y_pred)
r_score_3000
#r_score10=0.8577898390283567
# Out:
# -2.0119256717238607

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='friedman_mse', splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6892277554665034

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='friedman_mse', splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.7178081624976222

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='friedman_mse', max_features='sqrt',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.7014477889216102

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='friedman_mse', max_features='sqrt',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6830258323608916

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='friedman_mse', max_features='log2',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.46475586155950455

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='friedman_mse', max_features='log2',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6812453202697198

# %%
#4Using DT absolute_error
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='absolute_error', max_features='auto',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6758234634825413

# %%
#4Using DT absolute_error
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='absolute_error', max_features='auto',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.7261802422377626

# %%
#4Using DT absolute_error
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='absolute_error', max_features='sqrt',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6854546561635153

# %%
#4Using DT absolute_error
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='absolute_error', max_features='sqrt',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6888028482209169

# %%
#4Using DT absolute_error
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='absolute_error', max_features='log2',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.705615954049486

# %%
#4Using DT absolute_error
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='absolute_error', max_features='log2',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.7190631330276361

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='squared_error', max_features='auto',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6913672691530341

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='squared_error', max_features='auto',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.7081590662897808

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='squared_error', max_features='sqrt',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6542744786124377

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='squared_error', max_features='sqrt',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6435564946450671

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='squared_error', max_features='log2',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.7357248800926344

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='squared_error', max_features='log2',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.7111993283843301

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='poisson', max_features='auto',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6821924535244689

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='poisson', max_features='auto',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6610072456800803

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='poisson', max_features='sqrt',splitter='best')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.5428627746861965

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='poisson', max_features='sqrt',splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6574574090080637

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='poisson', max_features='log2')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6478100938212751

# %%
#4Using DT friedman_mse
from sklearn.tree import DecisionTreeRegressor
DT_regressor = DecisionTreeRegressor(criterion='poisson', max_features='log2', splitter='random')
DT_regressor = DT_regressor.fit(x_train,y_train)
#model Created
DT_y_pred=DT_regressor.predict(x_test)

from sklearn.metrics import r2_score
DT_r_score=r2_score(y_test,DT_y_pred)
DT_r_score
# Out:
# 0.6023887715039826

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 50, random_state = 0)       
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %%
RF_y_pred=regressor.predict(x_test)
RF_y_pred
# Out:
# array([11887.5975132 , 11517.0980828 , 44485.890245  , 13409.265274  ,
#         9336.839947  , 10644.1829096 ,  1830.74274   , 10748.3614214 ,
#         8047.2558074 ,  5675.950137  ,  7543.8872458 , 16852.7628186 ,
#         9481.602034  ,  6599.5527894 , 25059.075536  , 11701.7815824 ,
#        13040.0162554 ,  3274.803959  ,  6385.131482  , 34151.635594  ,
#        23530.223396  , 14657.343454  , 11859.5352416 , 28331.2414462 ,
#         2384.6883586 ,  5433.5039702 ,  5236.6325502 ,  7933.9665796 ,
#         3732.934409  ,  9649.6577796 ,  7854.0596782 , 48406.0616646 ,
#        14269.443936  , 13197.0172588 , 16367.9226078 ,  3649.502618  ,
#        10316.4163722 , 37566.5950888 , 39585.812568  ,  3513.7132998 ,
#         9820.8623024 ,  3862.2212334 , 20595.165985  , 47229.853133  ,
#        37297.8497556 ,  3934.3224802 , 12413.9059624 ,  6550.6072    ,
#         4538.962989  , 13013.4125754 ,  4409.8816506 ,  4921.3657818 ,
# ...

# %%
from sklearn.metrics import r2_score
RF_r_score=r2_score(y_test,RF_y_pred)
RF_r_score
# Out:
# 0.8577557489409313

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 75, random_state = 0)       
regressor.fit(x_train, y_train)
RF_y_pred=regressor.predict(x_test)
#RF_y_pred
from sklearn.metrics import r2_score
RF_r_score=r2_score(y_test,RF_y_pred)
RF_r_score
# Out:
# 0.8610266970581251

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)       
regressor.fit(x_train, y_train)
RF_y_pred=regressor.predict(x_test)
#RF_y_pred
from sklearn.metrics import r2_score
RF_r_score=r2_score(y_test,RF_y_pred)
RF_r_score
# Out:
# 0.8601303844261876
