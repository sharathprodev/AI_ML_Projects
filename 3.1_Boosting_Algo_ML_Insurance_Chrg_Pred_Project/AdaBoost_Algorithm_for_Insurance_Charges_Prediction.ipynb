# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')
dataset = pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
input_var=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
output_var=dataset['charges']

# %%
input_var
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
output_var
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(input_var,output_var,test_size=1/3, random_state=0)

# %%
x_train
# Out:
#       age    bmi  children  sex_male  smoker_yes
# 482    18  31.35         0         0           0
# 338    50  32.30         1         1           1
# 356    46  43.89         3         1           0
# 869    25  24.30         3         0           0
# 182    22  19.95         3         1           0
# ...   ...    ...       ...       ...         ...
# 763    27  26.03         0         1           0
# 835    42  35.97         2         1           0
# 1216   40  25.08         0         1           0
# 559    19  35.53         0         1           0
# 684    33  18.50         1         0           0
#
# [892 rows x 5 columns]

# %%
x_test
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 578    52  30.200         1         1           0
# 610    47  29.370         1         0           0
# 569    48  40.565         2         1           1
# 1034   61  38.380         0         1           0
# 198    51  18.050         0         0           0
# ...   ...     ...       ...       ...         ...
# 261    20  26.840         1         0           1
# 1271   25  34.485         0         0           0
# 1313   19  34.700         2         0           1
# 2      28  33.000         3         1           0
# 405    52  38.380         2         0           0
#
# [446 rows x 5 columns]

# %%
y_train
# Out:
# 482      1622.1885
# 338     41919.0970
# 356      8944.1151
# 869      4391.6520
# 182      4005.4225
#            ...
# 763      3070.8087
# 835      7160.3303
# 1216     5415.6612
# 559      1646.4297
# 684      4766.0220
# Name: charges, Length: 892, dtype: float64

# %%
y_test
# Out:
# 578      9724.53000
# 610      8547.69130
# 569     45702.02235
# 1034    12950.07120
# 198      9644.25250
#            ...
# 261     17085.26760
# 1271     3021.80915
# 1313    36397.57600
# 2        4449.46200
# 405     11396.90020
# Name: charges, Length: 446, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 50, random_state = 0)       
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %%
RF_y_pred=regressor.predict(x_test)
RF_y_pred
# Out:
# array([11484.2830058 , 11512.0138988 , 44485.890245  , 13409.265274  ,
#         9336.839947  , 11329.724309  ,  1830.74274   , 10710.9025414 ,
#         8039.2212844 ,  5656.455726  ,  7808.316642  , 16852.7628186 ,
#         9481.602034  ,  6599.5527894 , 25059.075536  , 11459.6631794 ,
#        13040.0162554 ,  3274.803959  ,  6385.131482  , 34151.635594  ,
#        23530.223396  , 14135.2680734 , 11859.5352416 , 28194.1937832 ,
#         2384.6883586 ,  5398.4094952 ,  5236.6325502 ,  7761.579981  ,
#         3732.934409  ,  9649.6577796 ,  7671.1479966 , 48378.2082956 ,
#        14269.443936  , 13197.0172588 , 16270.6060898 ,  3649.502618  ,
#        10316.4163722 , 37501.6785908 , 39585.812568  ,  3513.7132998 ,
#         9820.8623024 ,  3842.7194524 , 20595.165985  , 47229.429113  ,
#        37297.8497556 ,  3934.3224802 , 12159.6166084 ,  6550.6072    ,
#         4538.962989  , 12973.9636954 ,  4409.8816506 ,  4921.3657818 ,
# ...

# %%
from sklearn.metrics import r2_score
RF_r_score=r2_score(y_test,RF_y_pred)
RF_r_score
# Out:
# 0.8555756449804232

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
# Initialize AdaBoostRegressor with DecisionTreeRegressor as the base estimator
regressor = AdaBoostRegressor(base_estimator=DecisionTreeRegressor(), n_estimators=100, random_state=0)

# Fit the regressor to the training data
regressor.fit(x_train, y_train)
# Make predictions on the test data
AdaBoost_y_pred = regressor.predict(x_test)
# Calculate R^2 score
from sklearn.metrics import r2_score
AdaBoost_r_score = r2_score(y_test, AdaBoost_y_pred)

print("AdaBoost R^2 Score:", AdaBoost_r_score)
# Out:
# AdaBoost R^2 Score: 0.8470780420784317
